# %%
from aicsimageio import AICSImage
import napari as na
from glob import glob
from os.path import join
from pathlib import Path

# %%
viewer = na.Viewer()
# Out:
# Invalid schema for package 'ome-types', please run 'npe2 validate ome-types' to check for manifest errors.

# %%
folder = r"T:\MIGRATED\Lab_Members\Daniel_Foust\Data\Basal Bodies\fla-che induction\Inducible Bio Rep 1"
files = glob(join(folder, '*027.dv'))
print(len(files))
# Out:
# 1

# %%
for file in files:
    movie= AICSImage(file)
    movie_name = Path(file).stem
    viewer.add_image(movie.data.squeeze(), name=movie_name, visible=False)

# %%
import pandas as pd
tracks = pd.read_csv(r"T:\MIGRATED\Lab_Members\Daniel_Foust\Data\Basal Bodies\fla-che induction\Inducible Bio Rep 1\2023-07-05_rois_g-r_radsym_cons_var-c\DK31_1525fstG_85TIRF_250ms1min_flaskD_30mininc_39mintot_027.locs")
