# %% [markdown]
# ## imports

# %%
import matplotlib.pyplot as plt
import numpy as np
from os.path import join
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## intial experiments in T7, normal maintenance media

# %%
folder1 = r'T:\MIGRATED\Lab_Members\Daniel_Foust\Data\Basal Bodies\mutants\Strains Bio Rep 1\2023-06-29__rois_g-r_radsym_cons'
file1 = r'mobility results.csv'
data1 = pd.read_csv(join(folder1, file1), index_col=0)
data1['rep'] = 1

folder2 = r'T:\MIGRATED\Lab_Members\Daniel_Foust\Data\Basal Bodies\mutants\Strains Bio Rep 2\2023-06-29__rois_g-r_radsym_cons'
file2 = r'mobility results.csv'
data2 = pd.read_csv(join(folder2, file2), index_col=0)
data2['rep'] = 2

folder3 = r'T:\MIGRATED\Lab_Members\Daniel_Foust\Data\Basal Bodies\mutants\Strains Bio Rep 3\2023-06-29__rois_g-r_radsym_cons'
file3 = r'mobility results.csv'
data3 = pd.read_csv(join(folder3, file3), index_col=0)
data3['rep'] = 3

folder4 = r'T:\MIGRATED\Lab_Members\Daniel_Foust\Data\Basal Bodies\mutants\DB841 - 3 replicates\BR1\2023-06-29__rois_g-r_radsym_cons'
file4 = r'mobility results.csv'
data4 = pd.read_csv(join(folder4, file4), index_col=0)
data4['rep'] = 1

folder5 = r'T:\MIGRATED\Lab_Members\Daniel_Foust\Data\Basal Bodies\mutants\DB841 - 3 replicates\BR2\2023-06-29__rois_g-r_radsym_cons'
file5 = r'mobility results.csv'
data5 = pd.read_csv(join(folder5, file5), index_col=0)
data5['rep'] = 2

folder6 = r'T:\MIGRATED\Lab_Members\Daniel_Foust\Data\Basal Bodies\mutants\DB841 - 3 replicates\BR3\2023-06-29__rois_g-r_radsym_cons'
file6 = r'mobility results.csv'
data6 = pd.read_csv(join(folder6, file6), index_col=0)
data6['rep'] = 3

folder7 = r'T:\MIGRATED\Lab_Members\Daniel_Foust\Data\Basal Bodies\mutants\FliF Truncations and Mot Rep 1\2023-06-29__rois_g-r_radsym_cons'
file7 = r'mobility results.csv'
data7 = pd.read_csv(join(folder7, file7), index_col=0)
data7['rep'] = 1

folder8 = r'T:\MIGRATED\Lab_Members\Daniel_Foust\Data\Basal Bodies\mutants\20230911_FliFMotRep2\2023-06-29__rois_g-r_radsym_cons'
file8 = r'mobility results.csv'
data8 = pd.read_csv(join(folder8, file8), index_col=0)
data8['rep'] = 2

folder9 = r'T:\MIGRATED\Lab_Members\Daniel_Foust\Data\Basal Bodies\mutants\FliFTrunc Mot Rep 3\2023-06-29__rois_g-r_radsym_cons'
file9 = r'mobility results.csv'
data9 = pd.read_csv(join(folder9, file9), index_col=0)
data9['rep'] = 3

folder10 = r'T:\MIGRATED\Lab_Members\Daniel_Foust\Data\Basal Bodies\mutants\Missing from Bio Rep 3 Caroline Dunn\2023-06-29__rois_g-r_radsym_cons'
file10 = r'mobility results.csv'
data10 = pd.read_csv(join(folder10, file10), index_col=0)
data10['rep'] = 3

folder11 = r'T:\MIGRATED\Lab_Members\Daniel_Foust\Data\Basal Bodies\mutants\DK5083 from Bio Rep 2\2023-06-29__rois_g-r_radsym_cons'
file11 = r'mobility results.csv'
data11 = pd.read_csv(join(folder11, file11), index_col=0)
data11['rep'] = 2

folder12 = r'T:\MIGRATED\Lab_Members\Daniel_Foust\Data\Basal Bodies\mutants\20230705_repeat_DK479\2023-06-29__rois_g-r_radsym_cons'
file12 = r'mobility results.csv'
data12 = pd.read_csv(join(folder12, file12), index_col=0)
data12['rep'] = 2

data_composite = pd.concat([data1, data2, data3, data4, data5, data6, data7, data8, data9,
                            data10, data11, data12], axis=0, ignore_index=True)

strains_ordered = ['DK1906', 'DK5082', 'DK5081', 'DK5268', 'DK5083', 'DK5084', 'DK4892', 'DK479', 'DK9057', 'DK2118', 'DK8583',
                   'DB841',
                   'DB842', 'DB843', 'DB873', 'DB897', 
                   'DK4347']

# %%
data_composite['% Mobile'] = 100 * data_composite['f_mobile mean']

# %%
boxprops = {'facecolor': 4*[0]}

pal = sns.color_palette('rocket', n_colors=3)

fig, ax = plt.subplots(1,1, figsize=(8,4))
sns.boxplot(data=data_composite, x='strain', y='% Mobile', showfliers=False, boxprops=boxprops, order=strains_ordered)
sns.stripplot(data=data_composite, x='strain', y='% Mobile', hue='rep', order=strains_ordered,
                palette=pal)
plt.xticks(rotation='vertical')
ax.set_yscale('log')
ax.set_xlim([-1,17])
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0, fontsize=14)
plt.ylabel('% Mobile', fontsize=16)
plt.xlabel('Strain', fontsize=16)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)

# plt.savefig(join(r'T:\MIGRATED\Lab_Members\Daniel_Foust\Data\Basal Bodies\mutants', '% mobile all bio replicates 2023-10-12 update.png'),
#            dpi=600,
#            transparent=True,
#            bbox_inches='tight')
;
;
# Out:
# c:\Users\djfoust\Anaconda3\envs\napari-env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\djfoust\Anaconda3\envs\napari-env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\djfoust\Anaconda3\envs\napari-env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
summary_folder = r"T:\MIGRATED\Lab_Members\Daniel_Foust\Data\Basal Bodies\mutants"
summary_file = r"bb mutants all mobility estimates with particles.xlsx"

summary_data = pd.read_excel(join(summary_folder, summary_file), sheet_name=None, index_col=0)

# %%
all_dfs = [summary_data[strain] for strain in strains_ordered]
composite_df = pd.concat(all_dfs, axis=0, ignore_index=True)

# %%
composite_df['% Mobile Particles'] = composite_df['f_mobile_particles'] * 100
composite_df['% Mobile Particles (weighted)'] = composite_df['f_mobile_particles_weighted'] * 100

# %%
boxprops = {'facecolor': 4*[0]}

pal = sns.color_palette('rocket', n_colors=3)

fig, ax = plt.subplots(1,1, figsize=(8,4))
sns.boxplot(data=composite_df, x='strain', y='% Mobile Particles (weighted)', showfliers=False, boxprops=boxprops, order=strains_ordered)
sns.stripplot(data=composite_df, x='strain', y='% Mobile Particles (weighted)', hue='rep', order=strains_ordered,
                palette=pal)
# sns.stripplot(data=all_mobility_data, x='strain', y='f_mobile_particles_weighted', hue='rep', order=strains,
#                 palette=pal)
plt.xticks(rotation='vertical')
ax.set_yscale('log')
ax.set_xlim([-1,17])
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0, fontsize=14)
plt.ylabel('% Mobile Particles \n(weighted)', fontsize=16)
plt.xlabel('Strain', fontsize=16)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)

plt.savefig(join(r'T:\MIGRATED\Lab_Members\Daniel_Foust\Data\Basal Bodies\mutants', '% mobile particles (weighted) y-log 2023-10-19.png'),
           dpi=600,
           transparent=True,
           bbox_inches='tight')
;

fig, ax = plt.subplots(1,1, figsize=(8,4))
sns.boxplot(data=composite_df, x='strain', y='% Mobile Particles (weighted)', showfliers=False, boxprops=boxprops, order=strains_ordered)
sns.stripplot(data=composite_df, x='strain', y='% Mobile Particles (weighted)', hue='rep', order=strains_ordered,
                palette=pal)
# sns.stripplot(data=all_mobility_data, x='strain', y='f_mobile_particles_weighted', hue='rep', order=strains,
#                 palette=pal)
plt.xticks(rotation='vertical')
# ax.set_yscale('log')
ax.set_xlim([-1,17])
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0, fontsize=14)
plt.ylabel('% Mobile Particles \n(weighted)', fontsize=16)
plt.xlabel('Strain', fontsize=16)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)

plt.savefig(join(r'T:\MIGRATED\Lab_Members\Daniel_Foust\Data\Basal Bodies\mutants', '% mobile particles (weighted) y-linear 2023-10-19.png'),
           dpi=600,
           transparent=True,
           bbox_inches='tight')
;
# Out:
# c:\Users\djfoust\Anaconda3\envs\napari-env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\djfoust\Anaconda3\envs\napari-env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\djfoust\Anaconda3\envs\napari-env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
boxprops = {'facecolor': 4*[0]}

pal = sns.color_palette('rocket', n_colors=3)

fig, ax = plt.subplots(1,1, figsize=(8,4))
sns.boxplot(data=composite_df, x='strain', y='% Mobile Particles', showfliers=False, boxprops=boxprops, order=strains_ordered)
sns.stripplot(data=composite_df, x='strain', y='% Mobile Particles', hue='rep', order=strains_ordered,
                palette=pal)
plt.xticks(rotation='vertical')
ax.set_yscale('log')
ax.set_xlim([-1,17])
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0, fontsize=14)
plt.ylabel('% Mobile Particles', fontsize=16)
plt.xlabel('Strain', fontsize=16)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13);

plt.savefig(join(r'T:\MIGRATED\Lab_Members\Daniel_Foust\Data\Basal Bodies\mutants', '% mobile particles y-log 2023-10-19.png'),
           dpi=600,
           transparent=True,
           bbox_inches='tight');

fig, ax = plt.subplots(1,1, figsize=(8,4))
sns.boxplot(data=composite_df, x='strain', y='% Mobile Particles', showfliers=False, boxprops=boxprops, order=strains_ordered)
sns.stripplot(data=composite_df, x='strain', y='% Mobile Particles', hue='rep', order=strains_ordered,
                palette=pal)
plt.xticks(rotation='vertical')
# ax.set_yscale('log')
ax.set_xlim([-1,17])
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0, fontsize=14)
plt.ylabel('% Mobile Particles', fontsize=16)
plt.xlabel('Strain', fontsize=16)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13);

plt.savefig(join(r'T:\MIGRATED\Lab_Members\Daniel_Foust\Data\Basal Bodies\mutants', '% mobile particles y-linear 2023-10-19.png'),
           dpi=600,
           transparent=True,
           bbox_inches='tight');
# Out:
# c:\Users\djfoust\Anaconda3\envs\napari-env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\djfoust\Anaconda3\envs\napari-env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\djfoust\Anaconda3\envs\napari-env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
fig, ax = plt.subplots(1,1, figsize=(4,4))
sns.boxplot(data=data1, x='strain', y='f_mobile mean', boxprops=boxprops)
sns.stripplot(data=data1, x='strain', y='f_mobile mean')
plt.xticks(rotation='vertical');

# %%
fig, ax = plt.subplots(1,1, figsize=(4,4))
sns.boxplot(data=data2, x='strain', y='f_mobile mean')
sns.stripplot(data=data2, x='strain', y='f_mobile mean')
plt.xticks(rotation='vertical');

# %%
fig, ax = plt.subplots(1,1, figsize=(4,4))
sns.boxplot(data=data3, x='strain', y='f_mobile mean')
sns.stripplot(data=data3, x='strain', y='f_mobile mean')
plt.xticks(rotation='vertical');

# %%
fig, ax = plt.subplots(1,1, figsize=(7,4))
sns.boxplot(data=data_composite, x='strain', y='f_mobile mean', showfliers=False, boxprops=boxprops, order=strains_ordered)
sns.stripplot(data=data_composite, x='strain', y='f_mobile mean', hue='rep', order=strains_ordered)
plt.xticks(rotation='vertical')
ax.set_yscale('log')
ax.set_xlim([-1,17])
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0);

# %%
data_composite['% Mobile'] = 100 * data_composite['f_mobile mean']

# %%
help(sns.stripplot)
# Out:
# Help on function stripplot in module seaborn.categorical:
#
# stripplot(data=None, *, x=None, y=None, hue=None, order=None, hue_order=None, jitter=True, dodge=False, orient=None, color=None, palette=None, size=5, edgecolor='gray', linewidth=0, hue_norm=None, native_scale=False, formatter=None, legend='auto', ax=None, **kwargs)
#     Draw a categorical scatterplot using jitter to reduce overplotting.
#
#     A strip plot can be drawn on its own, but it is also a good complement
#     to a box or violin plot in cases where you want to show all observations
#     along with some representation of the underlying distribution.
#
#     .. note::
#         By default, this function treats one of the variables as categorical
#         and draws data at ordinal positions (0, 1, ... n) on the relevant axis.
#         This can be disabled with the `native_scale` parameter.
#
#         See the :ref:`tutorial <categorical_tutorial>` for more information.
#
#     Parameters
#     ----------
# ...

# %%
pal = sns.color_palette('rocket', n_colors=3)

fig, ax = plt.subplots(1,1, figsize=(8,4))
sns.boxplot(data=data_composite, x='strain', y='% Mobile', showfliers=False, boxprops=boxprops, order=strains_ordered)
sns.stripplot(data=data_composite, x='strain', y='% Mobile', hue='rep', order=strains_ordered,
                palette=pal)
plt.xticks(rotation='vertical')
ax.set_yscale('log')
ax.set_xlim([-1,17])
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0, fontsize=14)
plt.ylabel('% Mobile', fontsize=16)
plt.xlabel('Strain', fontsize=16)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)

plt.savefig(join(r'T:\MIGRATED\Lab_Members\Daniel_Foust\Data\Basal Bodies\mutants', '% mobile all bio replicates DB842-DB897 included.png'),
           dpi=600,
           transparent=True,
           bbox_inches='tight')
;
;
# Out:
# ''

# %%
fig, ax = plt.subplots(1,1, figsize=(6,4))
sns.boxplot(data=data_composite, x='strain', y='% Mobile', showfliers=False, boxprops=boxprops, order=strains_ordered)
sns.stripplot(data=data_composite, x='strain', y='% Mobile', hue='rep', order=strains_ordered)
plt.xticks(rotation='vertical')
# ax.set_yscale('log')
ax.set_xlim([-1,13])
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0);

# %% [markdown]
# # conditions / replicates

# %%
folder = r"t:\MIGRATED\Lab_Members\Daniel_Foust\Data\Basal Bodies\mutants\Condition Changes"
fname = r"mobility results summary.xlsx"

data = pd.read_excel(join(folder, fname), index_col=0, sheet_name=None)
data_DB841 = data['DB841']
data_DB843 = data['DB843']
data_DK5081 = data['DK5081']
data_DK5082 = data['DK5082']

data_DK5082 = pd.concat([data_DK5082, data_DK5081],
                        ignore_index=True)

data_DB841['% mobile_particles'] = data_DB841['f_mobile_particles'] * 100
data_DB841['% mobile_particles_weighted'] = data_DB841['f_mobile_particles_weighted'] * 100

data_DB843['% mobile_particles'] = data_DB843['f_mobile_particles'] * 100
data_DB843['% mobile_particles_weighted'] = data_DB843['f_mobile_particles_weighted'] * 100

# data_DK5081['% mobile_particles'] = data_DK5081['f_mobile_particles'] * 100
# data_DK5081['% mobile_particles_weighted'] = data_DK5081['f_mobile_particles_weighted'] * 100

data_DK5082['% mobile_particles'] = data_DK5082['f_mobile_particles'] * 100
data_DK5082['% mobile_particles_weighted'] = data_DK5082['f_mobile_particles_weighted'] * 100

# %%
pal = sns.color_palette('rocket', n_colors=3)
boxprops = {'facecolor': 4*[0]}

# %%
fig, ax = plt.subplots(1,1)

sns.boxplot(
    data=data_DB841, 
    x='Condition', 
    y='% mobile_particles',
    boxprops=boxprops,
    showfliers=False,
    )

sns.stripplot(
    data=data_DB841, 
    x='Condition', 
    y='% mobile_particles', 
    hue='Rep', 
    palette=pal,
    size=8,
    )

ax.set_ybound(lower=0, upper=25)

plt.legend(fontsize=14)
plt.ylabel('% Mobile Particles', fontsize=16)
plt.xlabel('Condition', fontsize=16)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13);
# Out:
# c:\Users\djfoust\Anaconda3\envs\napari-env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\djfoust\Anaconda3\envs\napari-env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\djfoust\Anaconda3\envs\napari-env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
fig, ax = plt.subplots(1,1)

sns.boxplot(
    data=data_DB843, 
    x='Condition', 
    y='% mobile_particles',
    boxprops=boxprops,
    showfliers=False,
    )

sns.stripplot(
    data=data_DB843, 
    x='Condition', 
    y='% mobile_particles', 
    hue='Rep', 
    palette=pal,
    size=8,
    )

ax.set_ybound(lower=0, upper=25)

plt.legend(fontsize=14)
plt.ylabel('% Mobile Particles', fontsize=16)
plt.xlabel('Condition', fontsize=16)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13);
# Out:
# c:\Users\djfoust\Anaconda3\envs\napari-env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\djfoust\Anaconda3\envs\napari-env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\djfoust\Anaconda3\envs\napari-env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
fig, ax = plt.subplots(1,1)

sns.boxplot(
    data=data_DK5081, 
    x='Condition', 
    y='% mobile_particles',
    boxprops=boxprops,
    showfliers=False,
    )

sns.stripplot(
    data=data_DK5081, 
    x='Condition', 
    y='% mobile_particles', 
    hue='Rep', 
    palette=pal,
    size=8,
    )

ax.set_ybound(lower=0, upper=25)

plt.legend(fontsize=14)
plt.ylabel('% Mobile Particles', fontsize=16)
plt.xlabel('Condition', fontsize=16)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13);
# Out:
# c:\Users\djfoust\Anaconda3\envs\napari-env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\djfoust\Anaconda3\envs\napari-env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\djfoust\Anaconda3\envs\napari-env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
fig, ax = plt.subplots(1,1)

sns.boxplot(
    data=data_DK5082, 
    x='Condition', 
    y='% mobile_particles',
    boxprops=boxprops,
    showfliers=False,
    )

sns.stripplot(
    data=data_DK5082, 
    x='Condition', 
    y='% mobile_particles', 
    hue='Rep', 
    palette=pal,
    size=8,
    )

ax.set_ybound(lower=0, upper=25)

plt.legend(fontsize=14)
plt.ylabel('% Mobile Particles', fontsize=16)
plt.xlabel('Condition', fontsize=16)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13);
# Out:
# c:\Users\djfoust\Anaconda3\envs\napari-env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\djfoust\Anaconda3\envs\napari-env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\djfoust\Anaconda3\envs\napari-env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# ## Conditions Round #2

# %%
folder = r"t:\MIGRATED\Lab_Members\Daniel_Foust\Data\Basal Bodies\mutants\Condition Changes 2"
fname = r"mobility results summary.xlsx"

data = pd.read_excel(join(folder, fname), index_col=0, sheet_name=None)
data_CH = data['CH']
data_LB = data['LB']
data_PBS = data['PBS']
data_WT = data['WT']

# data_DK5082 = pd.concat([data_DK5082, data_DK5081],
#                         ignore_index=True)

data_CH['% mobile_particles'] = data_CH['f_mobile_particles'] * 100
data_CH['% mobile_particles_weighted'] = data_CH['f_mobile_particles_weighted'] * 100

data_LB['% mobile_particles'] = data_LB['f_mobile_particles'] * 100
data_LB['% mobile_particles_weighted'] = data_LB['f_mobile_particles_weighted'] * 100

# data_DK5081['% mobile_particles'] = data_DK5081['f_mobile_particles'] * 100
# data_DK5081['% mobile_particles_weighted'] = data_DK5081['f_mobile_particles_weighted'] * 100

data_PBS['% mobile_particles'] = data_PBS['f_mobile_particles'] * 100
data_PBS['% mobile_particles_weighted'] = data_PBS['f_mobile_particles_weighted'] * 100

data_WT['% mobile_particles'] = data_WT['f_mobile_particles'] * 100
data_WT['% mobile_particles_weighted'] = data_WT['f_mobile_particles_weighted'] * 100

data_all = pd.concat((data_CH, data_LB, data_PBS, data_WT))

data_all.columns
# Out:
# Index(['Unnamed: 0', 'movie', 'strain', 'n', 'f_mobile mean', 'f_mobile stdev',
#        'f_mobile median', 'f_mobile_particles', 'f_mobile_particles_weighted',
#        'Rep', '% mobile_particles', '% mobile_particles_weighted'],
#       dtype='object')

# %%
boxprops = {'facecolor': 4*[0]}
pal = sns.color_palette('rocket', n_colors=3)

fig, ax = plt.subplots(1,1)

sns.boxplot(
    data=data_all, 
    x='strain', 
    y='% mobile_particles',
    boxprops=boxprops,
    showfliers=False,
    )

sns.stripplot(
    data=data_all, 
    x='strain', 
    y='% mobile_particles', 
    hue='Rep', 
    palette=pal,
    size=8,
    )

ax.set_ybound(lower=0)

plt.legend(fontsize=14)
plt.ylabel('% Mobile Particles', fontsize=16)
plt.xlabel('Condition', fontsize=16)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13);
# Out:
# c:\Users\djfoust\Anaconda3\envs\napari-env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\djfoust\Anaconda3\envs\napari-env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\djfoust\Anaconda3\envs\napari-env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# ## Small Batch Water

# %%
strains = ('DK1906', 'DK4347', 'DK479', 'DK5081')

folder = r"T:\MIGRATED\Lab_Members\Daniel_Foust\Data\Basal Bodies\mutants\Small Batch Water"
fname = r"mobility results summary.xlsx"


data_excel = pd.read_excel(join(folder, fname), sheet_name=None)
data_all = (data_excel[strain] for strain in strains)

data_all = pd.concat(data_all, ignore_index=True)

data_all['% mobile_particles'] = data_all['f_mobile_particles'] * 100
data_all['% mobile_particles_weighted'] = data_all['f_mobile_particles_weighted'] * 100

data_all.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'movie', 'strain', 'n', 'f_mobile mean',
#        'f_mobile stdev', 'f_mobile median', 'f_mobile_particles',
#        'f_mobile_particles_weighted', 'Rep', '% mobile_particles',
#        '% mobile_particles_weighted'],
#       dtype='object')

# %%
boxprops = {'facecolor': 4*[0]}
pal = sns.color_palette('rocket', n_colors=3)

fig, ax = plt.subplots(1,1)

sns.boxplot(
    data=data_all, 
    x='strain', 
    y='% mobile_particles',
    boxprops=boxprops,
    showfliers=False,
    )

sns.stripplot(
    data=data_all, 
    x='strain', 
    y='% mobile_particles', 
    hue='Rep', 
    palette=pal,
    size=8,
    )

ax.set_ybound(lower=0)

plt.legend(fontsize=14)
plt.ylabel('% Mobile Particles', fontsize=16)
plt.xlabel('Strain', fontsize=16)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13);
# Out:
# c:\Users\djfoust\Anaconda3\envs\napari-env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\djfoust\Anaconda3\envs\napari-env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\djfoust\Anaconda3\envs\napari-env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# ## in H20

# %%
fld1 = r"T:\MIGRATED\Lab_Members\Daniel_Foust\Data\Basal Bodies\mutants\Condition Changes 2\BR1\2023-06-29__rois_g-r_radsym_cons"
fn1 = r"mobility results br1.csv"
data1 = pd.read_csv(join(fld1, fn1))

fld2 = r"T:\MIGRATED\Lab_Members\Daniel_Foust\Data\Basal Bodies\mutants\Condition Changes 2\BR2\2023-06-29__rois_g-r_radsym_cons"
fn2 = r"mobility results br2.csv"
data2 = pd.read_csv(join(fld2, fn2))

fld3 = r"T:\MIGRATED\Lab_Members\Daniel_Foust\Data\Basal Bodies\mutants\Condition Changes 2\BR3\2023-06-29__rois_g-r_radsym_cons"
fn3 = r"mobility results br3.csv"
data3 = pd.read_csv(join(fld3, fn3))

# %%
data1 = data1[data1['strain']=='WT']
data2 = data2[data2['strain']=='WT']
data3 = data3[data3['strain']=='WT']

data1 = data1[data1['f_mobile_particles'] < 0.5]

data1['Rep'] = 1
data2['Rep'] = 3
data3['Rep'] = 1

data_dk5082 = pd.concat((data1,data2,data3), ignore_index=True)
data_dk5082['strain'] = 'DK5082'
data_dk5082
# Out:
#    Unnamed: 0                                              movie  strain  \
# 0          13  T:\MIGRATED\Lab_Members\Daniel_Foust\Data\Basa...  DK5082
# 1          12  T:\MIGRATED\Lab_Members\Daniel_Foust\Data\Basa...  DK5082
# 2          13  T:\MIGRATED\Lab_Members\Daniel_Foust\Data\Basa...  DK5082
# 3          14  T:\MIGRATED\Lab_Members\Daniel_Foust\Data\Basa...  DK5082
# 4          15  T:\MIGRATED\Lab_Members\Daniel_Foust\Data\Basa...  DK5082
# 5          10  T:\MIGRATED\Lab_Members\Daniel_Foust\Data\Basa...  DK5082
# 6          11  T:\MIGRATED\Lab_Members\Daniel_Foust\Data\Basa...  DK5082
#
#       n  f_mobile mean  f_mobile stdev  f_mobile median  f_mobile_particles  \
# 0  1775       0.036834        0.003581         0.036620            0.167019
# 1  2964       0.037719        0.003598         0.037787            0.155213
# 2  1981       0.040757        0.003936         0.040888            0.180921
# 3  1844       0.049328        0.004783         0.049078            0.188006
# ...

# %% [markdown]
# ## All data in water

# %%
## small batch
strains = ('DK1906', 'DK4347', 'DK479', 'DK5081',) 
folder = r"T:\MIGRATED\Lab_Members\Daniel_Foust\Data\Basal Bodies\mutants\Small Batch Water"
fname = r"mobility results summary.xlsx"

data_excel = pd.read_excel(join(folder, fname), sheet_name=None)
data_sb = (data_excel[strain] for strain in strains) # small batch

data_sb = pd.concat(data_sb, ignore_index=True)

# round 2
strains = ('DB1338', 'DB897', 'DK2118', 'DK4892', 'DK5083', 'DK5084', 'DK5268')
folder = r"T:\MIGRATED\Lab_Members\Daniel_Foust\Data\Basal Bodies\mutants\Water Batch 2"
fname = r"mobility results summary.xlsx"

data_excel = pd.read_excel(join(folder, fname), sheet_name=None)
data_r2 = (data_excel[strain] for strain in strains) # small batch
data_r2 = pd.concat(data_r2, ignore_index=True)

# round 3
strains = ('DB841', 'DB842', 'DB843', 'DB873')
folder = r"T:\MIGRATED\Lab_Members\Daniel_Foust\Data\Basal Bodies\mutants\Water Batch 3"
fname = r"mobility results summary.xlsx"

data_excel = pd.read_excel(join(folder, fname), sheet_name=None)
data_r3 = (data_excel[strain] for strain in strains) # small batch
data_r3 = pd.concat(data_r3, ignore_index=True)

# round 4
strains = ('DB1359', 'DK8583', 'DK5082')
folder = r"T:\MIGRATED\Lab_Members\Daniel_Foust\Data\Basal Bodies\mutants\Water Batch 4"
fname = r"mobility results summary.xlsx"

data_excel = pd.read_excel(join(folder, fname), sheet_name=None)
data_r4 = (data_excel[strain] for strain in strains) # small batch
data_r4 = pd.concat(data_r4, ignore_index=True)

# round 5
strains = ('DB1673', 'DK7871', 'DK7872', 'DK9675')
folder = r'T:\MIGRATED\Lab_Members\Daniel_Foust\Data\Basal Bodies\mutants\Water Batch 5'
fname = r'Water Batch 5 mobility results summary.xlsx'

data_excel = pd.read_excel(join(folder, fname), sheet_name=None)
data_r5 = (data_excel[strain] for strain in strains)
data_r5 = pd.concat(data_r5, ignore_index=True)

# combine
data_all = pd.concat((data_sb, data_r2, data_r3, data_r4, data_dk5082, data_r5), ignore_index=True)

data_all['% mobile_particles'] = data_all['f_mobile_particles'] * 100
data_all['% mobile_particles_weighted'] = data_all['f_mobile_particles_weighted'] * 100

# %%
save_folder = r"T:\MIGRATED\Lab_Members\Daniel_Foust\Data\Basal Bodies\mutants\plots"
save_name = r"% mobile bb - updated 2024-02-08.svg"

boxprops = {'facecolor': 4*[0]}
pal = sns.color_palette('rocket', n_colors=3)

fig, ax = plt.subplots(1,1)

sns.boxplot(
    data=data_all, 
    x='strain', 
    y='% mobile_particles',
    boxprops=boxprops,
    showfliers=False,
    )

sns.stripplot(
    data=data_all, 
    x='strain', 
    y='% mobile_particles', 
    hue='Rep', 
    palette=pal,
    size=8,
    )

ax.set_ybound(lower=0)

plt.legend(fontsize=14)
plt.ylabel('% Mobile Particles', fontsize=16)
plt.xlabel('Strain', fontsize=16)
plt.xticks(fontsize=13, rotation='vertical')
plt.yticks(fontsize=13)

# plt.savefig(join(save_folder, save_name),
#             dpi=600,
#             transparent=True,
#             bbox_inches='tight')
# ;
# Out:
# c:\Users\djfoust\Anaconda3\envs\napari-env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\djfoust\Anaconda3\envs\napari-env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\djfoust\Anaconda3\envs\napari-env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
strain_to_genotype = {
    'DK1906': r'wild type',
    'DK4347': r'$\Delta hag$',
    'DK4892': r'$\Delta flgE$',
    'DK5082': r'$\Delta flgB$',
    'DK5268': r'$\Delta flgC$',
    'DK5083': r'$\Delta flhO$',
    'DK5084': r'$\Delta flhP$',
    'DK5081': r'$\Delta fliE$',
    'DK2118': r'$\Delta flhF$',
    'DK479': r'$\Delta swrB$',
    'DB1338': r'$\Delta fliE\ \Delta swrB\ \Delta flhF$',
    'DB841': r'$fliF^{\Delta 297-351}$',
    'DB842': r'$fliF^{\Delta 289-351}$',
    'DB843': r'$fliF^{\Delta 280-360}$',
    'DB873': r'$fliF^{\Delta 311-338}$',
    'DB897': r'$\Delta motAB$'
}

# %%
data_all['genotype'] = data_all['strain'].map(strain_to_genotype)
data_all;

# %%
genotype_order = (r'wild type',
                    r'$\Delta swrB$',
                    r'$\Delta fliE\ \Delta swrB\ \Delta flhF$',
                    r'$\Delta fliE$',
                    r'$\Delta flgB$',
                    r'$\Delta flgC$',
                    r'$\Delta flhO$',
                    r'$\Delta flhP$',
                    r'$\Delta flgE$',
                        r'$fliF^{\Delta 311-338}$',
                        r'$fliF^{\Delta 297-351}$',
                        r'$fliF^{\Delta 289-351}$',
                        r'$fliF^{\Delta 280-360}$',
                            r'$\Delta hag$',
                            r'$\Delta motAB$',
                            r'$\Delta flhF$',)

genotype_colors = {r'wild type': 'xkcd:gray',
                    r'$\Delta swrB$': 'xkcd:lavender',
                    r'$\Delta fliE\ \Delta swrB\ \Delta flhF$': 'xkcd:lavender',
                    r'$\Delta fliE$': 'xkcd:cyan',
                    r'$\Delta flgB$': 'xkcd:cyan',
                    r'$\Delta flgC$': 'xkcd:cyan',
                    r'$\Delta flhO$': 'xkcd:cyan',
                    r'$\Delta flhP$': 'xkcd:cyan',
                    r'$\Delta flgE$': 'xkcd:bright blue',
                        r'$fliF^{\Delta 311-338}$': 'xkcd:light orange',
                        r'$fliF^{\Delta 297-351}$': 'xkcd:light orange',
                        r'$fliF^{\Delta 289-351}$': 'xkcd:light orange',
                        r'$fliF^{\Delta 280-360}$': 'xkcd:light orange',
                            r'$\Delta hag$': 'xkcd:light yellow',
                            r'$\Delta motAB$': 'xkcd:light yellow',
                            r'$\Delta flhF$': 'xkcd:light yellow'}

boxprops = {'facecolor': 4*[0]}
pal = sns.color_palette('rocket', n_colors=3)

fig, ax = plt.subplots(1, 1, figsize=(10,5))

sns.boxplot(
    data=data_all, 
    x='genotype', 
    y='% mobile_particles',
    # boxprops=boxprops,
    palette=genotype_colors,
    showfliers=False,
    order=genotype_order,
    )

sns.stripplot(
    data=data_all, 
    x='genotype', 
    y='% mobile_particles', 
    # hue='Rep', 
    # palette=pal,
    size=5,
    color='xkcd:black',
    order=genotype_order
    )

ax.set_ybound(lower=0, upper=35)

# plt.legend(fontsize=14)
plt.ylabel('% Mobile Basal Bodies', fontsize=16)
plt.xlabel('Genotype', fontsize=16)
plt.xticks(fontsize=13, rotation='vertical')
plt.yticks(fontsize=13)
# Out:
# c:\Users\djfoust\Anaconda3\envs\napari-env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\djfoust\Anaconda3\envs\napari-env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\djfoust\Anaconda3\envs\napari-env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
flif_genotypes = (r'wild type',
                  r'$fliF^{\Delta 311-338}$',
                  r'$fliF^{\Delta 297-351}$',
                  r'$fliF^{\Delta 289-351}$',
                  r'$fliF^{\Delta 280-360}$',
                  )

data_flif = data_all[data_all['genotype'].isin(flif_genotypes)]

fig, ax = plt.subplots(1, 1, figsize=(6,5))

sns.boxplot(
    data=data_flif, 
    x='genotype', 
    y='% mobile_particles',
    order=flif_genotypes,
    # boxprops=boxprops,
    palette=genotype_colors,
    showfliers=False,
    )

sns.stripplot(
    data=data_flif, 
    x='genotype', 
    y='% mobile_particles', 
    # hue='Rep', 
    order=flif_genotypes,
    # hue='Rep', 
    # palette=pal,
    size=5,
    color='xkcd:black',
    # size=8,
    )

ax.set_ybound(lower=0, upper=35)

# plt.legend(fontsize=14)
plt.ylabel('% Mobile Basal Bodies', fontsize=20)
plt.xlabel('Genotype', fontsize=20)
plt.xticks(fontsize=16, rotation='vertical')
plt.yticks(fontsize=16);
# Out:
# c:\Users\djfoust\Anaconda3\envs\napari-env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\djfoust\Anaconda3\envs\napari-env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\djfoust\Anaconda3\envs\napari-env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
rod_genotypes = (
    r'wild type',
    r'$\Delta swrB$',
    r'$\Delta fliE\ \Delta swrB\ \Delta flhF$',
    r'$\Delta fliE$',
    r'$\Delta flgB$',
    r'$\Delta flgC$',
    r'$\Delta flhO$',
    r'$\Delta flhP$',
    r'$\Delta flgE$',
)

data_rod = data_all[data_all['genotype'].isin(rod_genotypes)]

fig, ax = plt.subplots(1, 1, figsize=(8,5))

sns.boxplot(
    data=data_rod, 
    x='genotype', 
    y='% mobile_particles',
    order=rod_genotypes,
    # boxprops=boxprops,
    palette=genotype_colors,
    showfliers=False,
    )

sns.stripplot(
    data=data_rod, 
    x='genotype', 
    y='% mobile_particles', 
    # hue='Rep', 
    order=rod_genotypes,
    # hue='Rep', 
    # palette=pal,
    size=5,
    color='xkcd:black',
    )

ax.set_ybound(lower=0, upper=35)

# plt.legend(fontsize=14)
plt.ylabel('% Mobile Basal Bodies', fontsize=20)
plt.xlabel('Genotype', fontsize=20)
plt.xticks(fontsize=16, rotation='vertical')
plt.yticks(fontsize=16);
# Out:
# c:\Users\djfoust\Anaconda3\envs\napari-env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\djfoust\Anaconda3\envs\napari-env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\djfoust\Anaconda3\envs\napari-env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
null_genotypes = (
    r'wild type',
    r'$\Delta hag$',
    r'$\Delta motAB$',
    r'$\Delta flhF$',
)

data_null = data_all[data_all['genotype'].isin(null_genotypes)]

fig, ax = plt.subplots(1, 1, figsize=(6,5))

sns.boxplot(
    data=data_null, 
    x='genotype', 
    y='% mobile_particles',
    order=null_genotypes,
    # boxprops=boxprops,
    palette=genotype_colors,
    showfliers=False,
    )

sns.stripplot(
    data=data_null, 
    x='genotype', 
    y='% mobile_particles', 
    # hue='Rep', 
    order=null_genotypes,
    # hue='Rep', 
    # palette=pal,
    size=5,
    color='xkcd:black',
    )

ax.set_ybound(lower=0, upper=35)

# plt.legend(fontsize=14)
plt.ylabel('% Mobile Basal Bodies', fontsize=20)
plt.xlabel('Genotype', fontsize=20)
plt.xticks(fontsize=16, rotation='vertical')
plt.yticks(fontsize=16);
# Out:
# c:\Users\djfoust\Anaconda3\envs\napari-env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\djfoust\Anaconda3\envs\napari-env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\djfoust\Anaconda3\envs\napari-env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# ### for water batch 5

# %%
data_r5['% mobile_particles'] = data_r5['f_mobile_particles'] * 100
data_r5['% mobile_particles_weighted'] = data_r5['f_mobile_particles_weighted'] * 100

fig, ax = plt.subplots(1, 1, figsize=(6,5))

boxprops = {'facecolor': 4*[0]}
pal = sns.color_palette('rocket', n_colors=3)

sns.boxplot(
    data=data_r5, 
    x='strain', 
    y='% mobile_particles',
    # order=null_genotypes,
    boxprops=boxprops,
    # palette=genotype_colors,
    showfliers=False,
    )

sns.stripplot(
    data=data_r5, 
    x='strain', 
    y='% mobile_particles', 
    hue='Rep', 
    # order=null_genotypes,
    # hue='Rep', 
    palette=pal,
    size=5,
    color='xkcd:black',
    )

ax.set_ybound(lower=0, upper=35)

# plt.legend(fontsize=14)
plt.ylabel('% Mobile Basal Bodies', fontsize=20)
plt.xlabel('Genotype', fontsize=20)
plt.xticks(fontsize=16, rotation='vertical')
plt.yticks(fontsize=16);
# Out:
# c:\Users\djfoust\Anaconda3\envs\napari-env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\djfoust\Anaconda3\envs\napari-env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\djfoust\Anaconda3\envs\napari-env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

# Create figure and gridspec
fig = plt.figure(figsize=(10, 6))
gs = fig.add_gridspec(2, 2, width_ratios=[4, 1], height_ratios=[1, 4])

# Main axis
ax_main = fig.add_subplot(gs[1, 0])

# Axis above main axis
ax_above = fig.add_subplot(gs[0, 0])

# Axis to the left of the main axis
ax_left = fig.add_subplot(gs[1, 1])

# Adjust spacing
plt.subplots_adjust(hspace=0.3, wspace=0.3)

# Example plots for demonstration
ax_main.plot([1, 2, 3], [4, 5, 6])
ax_above.plot([1, 2, 3], [7, 8, 9])
ax_left.plot([4, 5, 6], [1, 2, 3])

plt.show()
